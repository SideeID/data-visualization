# %%
import numpy as np

x = np.linspace(0,2*np.pi, 100)
cos_x = np.cos(x)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
_ = ax.plot(x, cos_x)

# %%
x = np.array([1, 2, 3])
y = np.array([4, 5, 6])

fig, ax = plt.subplots()
_ = ax.scatter(x, y)
_ = ax.set_xlabel('x axis')
_ = ax.set_ylabel('y axis')

# %%
# kategori = ['panas', 'dingin']
# jumlah = ['8, 5']

# fig, ax = plt.subplots()
# _ = ax.bar(kategori, jumlah)
# _ = ax.set_xlabel('kategori')
# _ = ax.set_ylabel('jumlah')
# _ = ax.set_title('penikmat kopi')

kategori = ['Panas', 'Dingin']
jumlah = [8, 5]

fig, ax = plt.subplots()
_ = ax.bar(kategori, jumlah)
_ = ax.set_xlabel('Kategori')
_ = ax.set_ylabel('Jumlah')
_ = ax.set_title( 'Penikmat Kopi')

# %%
import matplotlib.pyplot as plt

# Create a figure and axis
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('equal')

# Define data
MataKuliah = ['Matematika', 'Fisika', 'Kimia', 'Komputer', 'Bahasa']
Nilai = [80, 96, 65, 79, 82]

# Create the pie chart
ax.pie(Nilai, labels=MataKuliah, autopct="%1.2f%%")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn')

x = np.linspace(0, 8, 100)
y = 4 + 2 * np.sin(2 * x)

fig, ax = plt.subplots()
ax.plot(x, y, linewidth=2.8)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(-2, 8), yticks=np.arange(-2, 8))

plt.show()
# Out:
# C:\Users\Dimas Fajar\AppData\Local\Temp\ipykernel_14484\1651596384.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn')

np.random.seed(3)
x = 0.5 + np.arange(8)
y = np.random.uniform(2, 7, len(x))

fig, ax = plt.subplots()
ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()
# Out:
# C:\Users\Dimas Fajar\AppData\Local\Temp\ipykernel_808\2344914823.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn')

np.random.seed(3)
x = 4 + np.random.normal(0, 2, 24)
y = 4 + np.random.normal(0, 2, len(x))

sizes = np.random.uniform(15, 80, len(x))
colors = np.random.uniform(15, 80, len(x))

fig, ax = plt.subplots()
scatter = ax.scatter(x, y, s=sizes, c=colors, vmin=0, vmax=100)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

cbar = plt.colorbar(scatter)
cbar.set_label('Color Scale')

plt.show()
# Out:
# C:\Users\Dimas Fajar\AppData\Local\Temp\ipykernel_808\663308031.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

np.random.seed(1)
x = np.linspace(0, 8, 16)
y1 = 3 + 4 * x / 8 + np.random.uniform(0.0, 0.5, len(x))
y2 = 1 + 2 * x / 8 + np.random.uniform(0.0, 0.5, len(x))

fig, ax = plt.subplots()

ax.fill_between(x, y1, y2, alpha=0.5, linewidth=0)

ax.plot(x, (y1 + y2) / 2, linewidth=2)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()
